# %% [markdown]
# # &#x1F4D1; &nbsp; $\mathfrak {\color{#348ABD} {Resources \ and \ Tips}}$

# %% [markdown]
# # $\mathfrak {\color{#348ABD} {Books}}$

# %% [markdown]
# ## packtpub.com
# #### Practical Data Analysis (Hector Cuesta):
# https://www.packtpub.com/mapt/book/All%20Books/9781783280995
# #### Python Machine Learning (Sebastian Raschka):
# https://www.packtpub.com/mapt/book/All%20Books/9781783555130
# #### Building Machine Learning Systems with Python (Willi Richert, Luis Pedro Coelho):
# https://www.packtpub.com/mapt/book/All%20Books/9781782161400
# #### Python Unlocked (Arun Tigeraniya):
# https://www.packtpub.com/mapt/book/All%20Books/9781785885990
# #### Functional Python Programming (Steven Lott):
# https://www.packtpub.com/mapt/book/All%20Books/9781784396992
# #### Mastering Python for Finance (James Ma Weiming):
# https://www.packtpub.com/mapt/book/All%20Books/9781784394516
# https://github.com/jakevdp/PythonDataScienceHandbook

# %% [markdown]
# ## different sources
# #### Advanced R (Hadley Wickham):
# http://adv-r.had.co.nz/
# #### D3 Tips and Tricks v3.x (Malcolm Maclean):
# https://leanpub.com/D3-Tips-and-Tricks/read#leanpub-auto-html
#
# #### Python Data Science Handbook (Jake VanderPlas):
# https://www.safaribooksonline.com/library/view/python-data-science/9781491912126/
#
# https://github.com/jakevdp/PythonDataScienceHandbook
#
# http://nbviewer.jupyter.org/github/jakevdp/PythonDataScienceHandbook/tree/master/notebooks/
#
# #### Problem Solving with Algorithms and Data Structures using Python
# http://interactivepython.org/runestone/static/pythonds/index.html
#
# #### How to Think Like a Computer Scientist: Interactive Edition
# http://interactivepython.org/runestone/static/thinkcspy/index.html

# %% [markdown]
# # $\mathfrak {\color{#348ABD} {Links}}$

# %% [markdown]
# #### 100+ Free Data Science Books for 2017:
# http://www.learndatasci.com/free-data-science-books/
# #### 23 types of regression
# http://www.datasciencecentral.com/profiles/blogs/23-types-of-regression
# #### 52 Useful Machine Learning & Prediction APIs, updated:
# http://www.kdnuggets.com/2017/02/machine-learning-data-science-apis-updated.html?utm_content=bufferbb80f&utm_medium=social&utm_source=facebook.com&utm_campaign=buffer
# #### Ask a Data Scientist: The Bias vs. Variance Tradeoff
# http://insidebigdata.com/2014/10/22/ask-data-scientist-bias-vs-variance-tradeoff/
# #### Stanford. Department of Statistics:
# http://statweb.stanford.edu/~tibs/sta306bfiles/
# #### Mathematica for prediction algorithms
# https://mathematicaforprediction.wordpress.com/
# #### Awesome JavaScript:
# https://github.com/stoeffel/awesome-fp-js
# #### Latex Encoding:
# http://www.codecogs.com/latex/eqneditor.php?lang=en-us
# #### Latex Maths:
# https://en.wikibooks.org/wiki/LaTeX/Mathematics
# #### Deep Learning in R:
# http://www.rblog.uni-freiburg.de/2017/02/07/deep-learning-in-r/
# #### Implementing the Gradient Descent Algorithm in R
# https://www.r-bloggers.com/implementing-the-gradient-descent-algorithm-in-r/
# #### MLWave:
# http://mlwave.com/
# #### Wholesase Customer Data R
# https://rpubs.com/mcgraw/85405
# #### Planet SciPy
# https://planet.scipy.org/

# %% [markdown]
# # $\mathfrak {\color{#348ABD} {Packages}}$

# %% [markdown]
# ## R
# #### Bookdown (to write books and long-form articles/reports): https://bookdown.org/
# #### Caret (R package forcreating predictive models): http://topepo.github.io/caret/index.html
# #### Osmar: https://cran.r-project.org/web/packages/osmar/osmar.pdf
# https://journal.r-project.org/archive/2013-1/eugster-schlesinger.pdf
#
# ## Python
# #### Scikit-learn: http://scikit-learn.org/stable/index.html
# #### Statistics in Python Scipy: http://www.scipy-lectures.org/packages/statistics/index.html
# #### Seaborn: http://seaborn.pydata.org/index.html
# #### Pandas Visualization: http://pandas.pydata.org/pandas-docs/version/0.18.1/visualization.html
# #### Statsmodels Examples: http://statsmodels.sourceforge.net/0.6.0/examples/index.html

# %% [markdown]
# ## Java
# #### OpenML. Measure: https://www.openml.org/search?type=measure&from=100

# %% [markdown]
# ## JavaScripthttps:
# #### D3 Blocks: https://bl.ocks.org/

# %% [markdown]
# # $\mathfrak {\color{#348ABD} {Tip \ Library}}$

# %% [markdown]
# ## Code Tips

# %%
# Create interactive button
from IPython.core.display import HTML
hide_code = ''
HTML('''<script>code_show = true; 
function code_display() {
    if (code_show) {
        $('div.input').each(function(id) {
            if (id == 0 || $(this).html().indexOf('hide_code') > -1) {$(this).hide();}
        });
        $('div.output_prompt').css('opacity', 0);
    } else {
        $('div.input').each(function(id) {$(this).show();});
        $('div.output_prompt').css('opacity', 1);
    }
    code_show = !code_show;
} 
$(document).ready(code_display);</script>
<form action="javascript: code_display()"><input style="color: #348ABD; background: ghostwhite; opacity: 0.9; " \
type="submit" value="Click to display or hide code"></form>''')
# Out:
# <script>code_show = true;
# function code_display() {
#     if (code_show) {
#         $('div.input').each(function(id) {
#             if (id == 0 || $(this).html().indexOf('hide_code') > -1) {$(this).hide();}
#         });
#         $('div.output_prompt').css('opacity', 0);
#     } else {
#         $('div.input').each(function(id) {$(this).show();});
#         $('div.output_prompt').css('opacity', 1);
#     }
#     code_show = !code_show;
# }
# $(document).ready(code_display);</script>
# <form action="javascript: code_display()"><input style="color: #348ABD; background: ghostwhite; opacity: 0.9; " type="submit" value="Click to display or hide code"></form>

# %%
import matplotlib
import pygal
# %matplotlib inline
from IPython.core.display import SVG, HTML, Image

# %%
# pygal
html_pygal = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>   
  </head>
  <body>
    <figure>
      {pygal_render};
    </figure>
  </body>
</html>
"""

# %%
line_chart = pygal.Line()
line_chart.title = 'Browser usage evolution (in %)'
line_chart.x_labels = map(str, range(2002, 2013))
line_chart.add('Firefox', [None, None, 0, 16.6,   25,   31, 36.4, 45.5, 46.3, 42.8, 37.1])
line_chart.add('Chrome',  [None, None, None, None, None, None,    0,  3.9, 10.8, 23.8, 35.3])
line_chart.add('IE',      [85.8, 84.6, 84.7, 74.5,   66, 58.6, 54.7, 44.8, 36.2, 26.6, 20.1])
line_chart.add('Others',  [14.2, 15.4, 15.3,  8.9,    9, 10.4,  8.9,  5.8,  6.7,  6.8,  7.5])
HTML(html_pygal.format(pygal_render=line_chart.render()))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#   </head>
#   <body>
#     <figure>
# ...

# %%
# Convert sklearn data to pandas dataframes
import pandas as pd
import numpy as np
from sklearn import datasets
# %pylab inline
iris = datasets.load_iris()
data = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])
pd.scatter_matrix(data, figsize=(14,7));
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# test_bagging.py from sklearn/ensemble/tests
def test_regression():
    """Check regression for various parameter settings."""
    rng = check_random_state(0)
    X_train, X_test, y_train, y_test = train_test_split(boston.data[:50],
                                                        boston.target[:50],
                                                        random_state=rng)
    grid = ParameterGrid({"max_samples": [0.5, 1.0],
                          "max_features": [0.5, 1.0],
                          "bootstrap": [True, False],
                          "bootstrap_features": [True, False]})

    for base_estimator in [None,
                           DummyRegressor(),
                           DecisionTreeRegressor(),
                           KNeighborsRegressor(),
                           SVR()]:
        for params in grid:
            BaggingRegressor(base_estimator=base_estimator,
                             random_state=rng,
                             **params).fit(X_train, y_train).predict(X_test)

# %%
# Time measure
import time
start_time = time.time()
main()
print("--- %s seconds ---" % (time.time() - start_time))

# %%
Image('bokeh01.png')

# %%
Image('bokeh02.png')

# %% [markdown]
# ## Markdown Tips

# %% [markdown]
# ![](sklearn01.png)

# %% [markdown]
# ![](sklearn02.png)

# %% [markdown]
# *** Tables in Markdown***
#
# | Feature | Client 1 | Client 2 | Client 3 |
# | :---: | :---: | :---: | :---: |
# | Total number of rooms in home | 5 rooms | 4 rooms | 8 rooms |
# | Neighborhood poverty level (as %) | 17% | 32% | 3% |
# | Student-teacher ratio of nearby schools | 15-to-1 | 22-to-1 | 12-to-1 |

# %% [markdown]
# ##### Line separator
# ***

# %% [markdown]
# ##### Colors
# $$ \color{#00A0A0} {F_{\beta} = (1 + \beta^2) \cdot \frac{precision \cdot recall}{\left( \beta^2 \cdot precision \right) + recall}} $$

# %% [markdown]
# #### &#x1F499; &nbsp; <span style="color:blue">colors </span> &#x1F49A; &nbsp; <span style="color:green">in</span> &#x1F49B; &nbsp; <span style="color:orange">markdown </span>&#x1F49C; &nbsp;<span style="color:darkviolet">cells</span>
